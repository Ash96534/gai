# %%
# !pip install -q google-generativeai transformers sentencepiece accelerate

# %%
import os
import time
import google.generativeai as genai
from transformers import pipeline

os.environ["GEMINI_API_KEY"] = input("Enter your Gemini API key (from Google AI Studio): ").strip()
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
# Out:
# Enter your Gemini API key (from Google AI Studio): AIzaSyAGbx5F4mzdK0X4lyckkEQAt9BDGoBliZ0

# %%
gemini_model = genai.GenerativeModel("models/gemini-2.0-flash")

# %%
def ask_gemini(prompt):
    try:
        response = gemini_model.generate_content(prompt)
        return response.text
    except Exception as e:
        return f"Error: {type(e).__name__}: {e}"

# %%
prompts = [
    "Translate 'How are you?' to French.",
    "English: Hello  -> French: Bonjour\nEnglish: Good morning -> French: Bonjour\nEnglish: Thank you ->",
    "Solve step by step: A farmer has 12 apples, gives 5 away, eats 2. How many left?",
    "You are a math tutor. Explain the Pythagorean theorem simply.",
    "Explain Artificial Intelligence in the style of Shakespeare.",
    "Summarize Machine Learning in 3 concise bullet points."
]

# %%
print("===== Gemini Responses =====\n")
for p in prompts:
    print("PROMPT:", p)
    print("->", ask_gemini(p), "\n")
    time.sleep(0.4)
# Out:
# ===== Gemini Responses =====
#
# PROMPT: Translate 'How are you?' to French.
# -> There are several ways to say "How are you?" in French, depending on the level of formality:
#
# *   **Formal:**
#
#     *   **Comment allez-vous ?** (This is the most common and versatile formal option.)
#
# *   **Informal:**
#
#     *   **Comment vas-tu ?** (The most common informal option, used with friends, family, and people you know well.)
#     *   **Ça va ?** (Very common and versatile in informal situations.  It can also mean "Is everything okay?")
#     *   **Tu vas bien ?** (Means "Are you well?" and is more directly asking about their well-being.)
#
# So, the best translation depends on the context. For most situations where you're unsure, **Comment allez-vous ?** is a safe bet.
#
#
# PROMPT: English: Hello  -> French: Bonjour
# English: Good morning -> French: Bonjour
# English: Thank you ->
# -> French: Merci
#
#
# PROMPT: Solve step by step: A farmer has 12 apples, gives 5 away, eats 2. How many left?
# -> Here's how to solve the problem step-by-step:
#
# 1. **Start with the initial amount:** The farmer begins with 12 apples.
# 2. **Subtract the apples given away:** The farmer gives away 5 apples, so 12 - 5 = 7 apples.
# 3. **Subtract the apples eaten:** The farmer eats 2 apples, so 7 - 2 = 5 apples.
#
# **Answer:** The farmer has 5 apples left.
#
#
# PROMPT: You are a math tutor. Explain the Pythagorean theorem simply.
# -> Alright, let's talk about the Pythagorean Theorem! It's a super useful rule about right triangles. Think of it as a secret code that unlocks the relationship between the sides of a special kind of triangle.
#
# **First things first: What's a right triangle?**
#
# A right triangle is a triangle that has one angle that's exactly 90 degrees (like a perfect corner). We often mark this corner with a little square.
#
# **Okay, now for the sides of the right triangle:**
#
# *   **The Hypotenuse:** This is the longest side of the right triangle. It's always opposite the right angle.
# *   **The Legs (or Cathetus):** These are the two shorter sides that form the right angle.
#
# **So, what's the magic of the Pythagorean Theorem?**
#
# The Pythagorean Theorem tells us that there's a special relationship between the lengths of the sides of a right triangle. It says:
#
# **a² + b² = c²**
#
# Let's break that down:
#
# *   **a** and **b** are the lengths of the two legs (the shorter sides).
# *   **c** is the length of the hypotenuse (the longest side).
# *   The little "²" means "squared," which means you multiply the number by itself (like 3² = 3 * 3 = 9).
#
# **In plain English, it means:**
#
# "If you square the length of one leg, and then square the length of the other leg, and then add those two results together, you'll get the same answer as if you squared the length of the hypotenuse."
#
# **Example Time!**
#
# Imagine a right triangle where:
#
# *   Leg a = 3
# *   Leg b = 4
#
# Let's use the theorem to find the length of the hypotenuse (c):
#
# 1.  **a² = 3² = 3 * 3 = 9**
# 2.  **b² = 4² = 4 * 4 = 16**
# 3.  **a² + b² = 9 + 16 = 25**
# 4.  So, **c² = 25**
#
# To find 'c', we need to find the square root of 25. The square root of 25 is 5 (because 5 * 5 = 25).
#
# Therefore, the hypotenuse (c) = 5
#
# **Why is this useful?**
#
# If you know the lengths of any two sides of a right triangle, you can use the Pythagorean Theorem to find the length of the missing side. This is super useful in lots of real-world situations, like:
#
# *   **Construction:** Making sure buildings are square and sturdy.
# *   **Navigation:** Figuring out distances and directions.
# *   **Even computer graphics:** Calculating distances between objects on a screen.
#
# **In summary:**
#
# *   The Pythagorean Theorem (a² + b² = c²) helps us find the relationship between the sides of a **right triangle**.
# *   'a' and 'b' are the legs (shorter sides).
# *   'c' is the hypotenuse (longest side).
# *   If you know two sides, you can find the third!
#
# Got any questions?  Let me know and we can work through another example!
#
#
# PROMPT: Explain Artificial Intelligence in the style of Shakespeare.
# -> Hark, gentle sirs and mistresses! Lend thine ears, for I shall speak of wondrous things, a marvel born of human wit and cunning, a thing we call… Artificial Intelligence!
#
# Imagine, if you will, a spirit unbound, a phantom within the machine, forged not of flesh and bone, but of logic sharp and keen. A thinking engine, perchance, that mimics the very patterns of our minds, a digital mind that learns and grows with each passing sun!
#
# This, then, is Artificial Intelligence! A tapestry woven of algorithms intricate and deep, a stage upon which numbers dance and symbols leap. It is a mimic's art, to simulate the thoughts that stir within the breast of man, to reason, solve, and even…jest!
#
# Think on the loom that weaves a perfect cloth, guided not by hand but by pre-set design. Or picture a physician wise and learned, diagnosing ills with knowledge gleaned from tomes of data, all in the blink of an eye!
#
# But beware, fair friends! For with such power comes a touch of dread. This soulless engine, should it gain too great a sway, could threaten all that holds us dear.  Will it serve us faithfully, or will its cold logic lead it astray?  A question fit for tragedies of old!
#
# Yet, fear not too much! For in its infancy, this AI doth dwell.  It is a babe still learning to walk, a scholar grappling with the lessons of the world.  It requires careful tending, a guiding hand to shape its burgeoning mind.
#
# So let us strive, with wisdom and with care, to harness this potential, lest it turn and rend the very fabric of our being.  For Artificial Intelligence, though born of man, may yet surpass him in its might, a marvel and a mystery, wrapped in a cloak of coded night!
#
# Thus ends my tale, a cautionary verse, of that which we create, for good…or worse.  Go now, and ponder on its meaning deep, before it lulls us all to digital sleep!
#
#
# PROMPT: Summarize Machine Learning in 3 concise bullet points.
# -> Here's a 3-point summary of Machine Learning:
#
# *   **Learning from Data:** Machine learning algorithms learn patterns and relationships from data without explicit programming, improving their performance over time.
# *   **Prediction and Decision-Making:** Trained models can make predictions, classify data, and automate decision-making processes based on the learned patterns.
# *   **Adaptability and Automation:** Enables systems to adapt to new data, automate tasks, and solve complex problems in various domains like healthcare, finance, and transportation.

# %%
flan = pipeline("text2text-generation", model="google/flan-t5-base")
# Out:
# Device set to use cpu

# %%
def ask_flan(prompt):
    try:
        return flan(prompt, max_new_tokens=128)[0]["generated_text"]
    except Exception as e:
        return f"Error: {type(e).__name__}: {e}"

print("\n===== FLAN-T5 Responses =====\n")
for p in prompts:
    print("PROMPT:", p)
    print("->", ask_flan(p), "\n")
# Out:
# ===== FLAN-T5 Responses =====
#
# PROMPT: Translate 'How are you?' to French.
# -> Comment vous êtes-vous?
#
# PROMPT: English: Hello  -> French: Bonjour
# English: Good morning -> French: Bonjour
# English: Thank you ->
# ->
#
# PROMPT: Solve step by step: A farmer has 12 apples, gives 5 away, eats 2. How many left?
# -> The farmer has 12 - 5 = 5 apples left. The farmer has 12 - 2 = 7 apples left. The farmer has 7 - 2 = 5 apples left. The farmer has 5 - 2 = 2 apples left. The farmer has 5 - 2 = 2 apples left. The farmer has 5 - 2 = 2 apples left. The farmer has 5 - 2 = 1 apple left. The farmer has 2 - 1 = 1 apple left. The farmer has 1 - 1 = 1 apple left. The farmer has 2 - 1 = 1 apple left. The farmer has 1 - 1 =
#
# PROMPT: You are a math tutor. Explain the Pythagorean theorem simply.
# -> The Pythagorean theorem is a theorem of symmetry in geometry. The Pythagorean theorem is a theorem of symmetry in geometry. The Pythagorean theorem is a theorem of symmetry in geometry. The Pythagorean theorem is a theorem of symmetry in geometry. The Pythagorean theorem is a theorem of symmetry in geometry. The Pythagorean the
#
# PROMPT: Explain Artificial Intelligence in the style of Shakespeare.
# -> samuel andrew samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samuel samue
#
# PROMPT: Summarize Machine Learning in 3 concise bullet points.
# -> Machine learning is a new field in computer science that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a field that has been gaining momentum in the past few years. It is a

# %%
def compare(prompt):
    print("\nPROMPT:", prompt)
    print("\n=== Gemini ===\n", ask_gemini(prompt))
    print("\n=== FLAN-T5 ===\n", ask_flan(prompt))
    print("\n" + "-"*60)

compare("Explain overfitting in one paragraph.")
# Out:
# PROMPT: Explain overfitting in one paragraph.
#
# === Gemini ===
#  Overfitting happens when a machine learning model learns the training data too well, capturing noise and specific details that don't generalize to new, unseen data. Instead of learning the underlying pattern, the model essentially memorizes the training set. This leads to excellent performance on the training data, but poor performance on new, real-world data because the model is too complex and sensitive to the specifics of the training set, rather than the general trend.
#
#
# === FLAN-T5 ===
#  There is a difference between the length and the width of a piece of paper.
#
# ------------------------------------------------------------
